# %% [markdown]
# # Space Objects DataFrame Analysis
# **Author**: [Student Name]
#
# I pledge that this work is my own, completed in accordance with course guidelines.
#
# ## Instructions
# For this exercise, you need the knowledge from the DataCamp lesson on `data.frame` objects and the plotting practice from class. For the last question, you need to look up a help page.
#
# **Goal**: Demonstrate your understanding of R data frames by creating, inspecting, subsetting, sorting, and visualizing data about space objects.
#
# **Tasks**:
# - Complete all tasks in this DataLab R notebook.
# - Add short comments in code cells to explain your output.
# - Answer questions in text blocks where specified.
# - Save the notebook as `Space_Objects_DataFrame.ipynb`.
# - Share the DataLab link in Canvas.
#
# ## Data
# Use the following table of eight space objects, also available as a CSV file at: [tinyurl.com/space-objects-csv](https://tinyurl.com/space-objects-csv)
#
# | object      | type      | diameter_km | composition | rings | hazard_level |
# |-------------|-----------|-------------|-------------|-------|--------------|
# | Jupiter     | Planet    | 139820      | Gas         | TRUE  | 8            |
# | Europa      | Moon      | 3122        | Ice         | FALSE | 4            |
# | Ceres       | Asteroid  | 946         | Rock        | FALSE | 5            |
# | Titan       | Moon      | 5150        | Ice         | FALSE | 6            |
# | Mars        | Planet    | 6792        | Rock        | FALSE | 7            |
# | Enceladus   | Moon      | 504         | Ice         | FALSE | 3            |
# | Io          | Moon      | 3643        | Rock        | FALSE | 9            |
# | Saturn      | Planet    | 116460      | Gas         | TRUE  | 10           |

# %% [markdown]
# ## 1. Create Vectors
#
# Create SIX vectors of equal length describing the eight space objects shown in the table above.

# %% [markdown]
# ## 2. Combine into a Data Frame
#
# Combine the vectors into a data frame called `space_objects_df` and print the data frame.

# %% [markdown]
# ## 3. Inspect the Data Frame
#
# Perform the following inspections on the data frame.

# %% [markdown]
# ### 3.1 Display First Four Rows
#
# Use `head` to display only the first four rows of the data frame.

# %% [markdown]
# ### 3.2 Display Last Four Rows
#
# Use `tail` to display the last four rows of the data frame.

# %% [markdown]
# ### 3.3 Show Structure
#
# Show the structure of the data frame.

# %% [markdown]
# ### 3.4 Summary Statistics
#
# Print summary statistics of the data frame.

# %% [markdown]
# ### 3.5 Questions
#
# Answer the following questions:
# 1. What is the average hazard level?
# 2. What data type is `rings`?
# 3. Is the object `type` a categorical variable?

# %% [markdown]
# **Answers**:
# 1.
# 2.
# 3.

# %% [markdown]
# ## 4. Select and Print
#
# Perform the following selections and print the results.

# %% [markdown]
# ### 4.1 Composition of "Titan"
#
# Select and print the composition of the object "Titan".

# %% [markdown]
# ### 4.2 Full Record for the 5th Object
#
# Select and print the full record for the 5th space object.

# %% [markdown]
# ### 4.3 `diameter_km` Column by Three Methods
#
# Select and print the `diameter_km` column using three methods: by index, by name, and with the accessor operator `$`.

# %% [markdown]
# #### By Index

# %% [markdown]
# #### By Name

# %% [markdown]
# #### Using Accessor Operator `$`

# %% [markdown]
# ## 5. Subset for One Feature
#
# Create a new data frame `ringed_df` containing only space objects that have rings using the `subset` function.

# %% [markdown]
# ## 6. Filter by Condition
#
# Create a new data frame `hazardous_ringed` that contains only space objects with rings that also have a hazard level above 6.

# %% [markdown]
# ## 7. Sort
#
# Sort `space_objects_df` by `diameter_km` from smallest to largest and store the result in `sorted_objects`.

# %% [markdown]
# ## 8. Histogram
#
# Make a histogram of space object diameters. Add a title and axis labels.

# %% [markdown]
# ### 8.1 Questions
#
# Answer the following questions:
# 1. What kind of variable is `diameter_km`?
# 2. What kind of histogram would you get if you plotted the `object` values instead?
# 3. What is the default binwidth?

# %% [markdown]
# **Answers**:
# 1.
# 2.
# 3.

# %% [markdown]
# ## 9. Scatter/Line Plot
#
# Plot `diameter_km` (y-axis) against `hazard_level` (x-axis) using `plot()`. Add a title, axis labels, and connect points with lines (`type = "b"`).

# %% [markdown]
# ### 9.1 Questions
#
# Answer the following questions:
# 1. Would it be better to connect the points with a line (`type="l"`)? Why or why not?
# 2. Should the measuring units be added to the "Hazard Level" label? Why or why not?
# 3. Could you just plot with x = hazard level? Why or why not?

# %% [markdown]
# **Answers**:
# 1.
# 2.
# 3.

# %% [markdown]
# ## 10. Combined Filtering and Labeling
#
# Create a new data frame `large_hazardous` containing only space objects with a diameter larger than 5000 km and with a hazard level above 6. Then make a scatter plot of their diameter vs. hazard level and label the points with their names using the `text` function. Refer to the help page (`?text`) to understand the `pos` parameter.

# %% [markdown]
# ## Submission Notes
#
# - Save this notebook as `Space_Objects_DataFrame.ipynb`.
# - Replace `[Student Name]` with your name in the author field.
# - Share the DataLab link in Canvas.
