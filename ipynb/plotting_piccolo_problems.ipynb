# %% [markdown]
# # Piccolo Problems: Exploring mtcars Dataset
#
# Date: Thursday, November 13, 2025, 08:04 PM CST
#
# Instructions: Complete the following 10 problems by writing and running R code in each cell. Use the `mtcars` dataset, which contains data for 32 cars. Fill in the code blocks and execute them to see the results. Each problem builds on the previous one.

# %% [markdown]
# ## Problem 1: Create a histogram of the horsepower data
# Create a histogram of the horsepower (`hp`) data of the 32 cars in the `mtcars` dataset. Run the code.

# %%
# Write your code here

# %% [markdown]
# ## Problem 2: Label the x-axis
# Label the x-axis of the histogram. Run the code.

# %%
# Write your code here

# %% [markdown]
# ## Problem 3: Label the y-axis
# Label the y-axis of the histogram. Run the code.

# %%
# Write your code here

# %% [markdown]
# ## Problem 4: Title the plot
# Add a title to the histogram. Run the code.

# %%
# Write your code here

# %% [markdown]
# ## Problem 5: Print the binwidth
# Print the binwidth used in the histogram. Run the code.

# %%
# Write your code here

# %% [markdown]
# ## Problem 6: Plot the logarithm of hp to base 10
# Create a histogram of the logarithm (base 10) of the `hp` data. Run the code.

# %%
# Write your code here

# %% [markdown]
# ## Problem 7: Plot car count for hp >= 220
# Create a histogram showing only the car count for cars with a horsepower of 220 or greater. Run the code.

# %%
# Write your code here

# %% [markdown]
# ## Problem 8: Update x-axis label with sub
# Change the x-axis label to automatically show 'hp >= 220'. Run the code.

# %%
# Write your code here

# %% [markdown]
# ## Problem 9: Plot array (top and bottom)
# Display the log10 plot and the original plot in one plot array, stacked vertically, without customization. Run the code.

# %%
# Write your code here

# %% [markdown]
# ## Problem 10: Plot array (side by side)
# Display the log10 plot and the original plot in one plot array, side by side, without customization. Run the code.

# %%
# Write your code here
